# %%
import pandas as pd,os

# %%
dflist = []
for filename in [x for x in os.listdir('./csv')]:
    dflist.append(pd.read_csv('./csv/'+filename))
df=pd.concat(dflist)
df.columns
df.groupby(by="Airport Name").agg('count').sort_values('Airport Code', ascending=0)
# Out:
#                                                   Airline Name  Airport Code  \
# Airport Name
# John F. Kennedy International                             8342          9232
# Newark International Airport                              5991          6866
# Chicago O'Hare International Airport                      5831          6843
# Los Angeles International Airport                         5089          6765
# Miami International Airport                               5504          6432
# Orlando International Airport                             5664          6394
# Hartsfield-Jackson Atlanta International Airport          5194          5871
# Seattle-Tacoma International                              4572          5396
# Phoenix Sky Harbor International                          4364          5086
# McCarran International                                    4394          5058
# Philadelphia International Airport                        4012          4674
# ...
